# %%
from lib.models.bisenetv2_contrast import BiSeNetV2_Contrast
import torch

# %%
from tools.configer import Configer

# %%
configer = Configer(configs='configs/bisenetv2_city_cam.json')

# %%
net = BiSeNetV2_Contrast(configer=configer)
# Out:
# BiSeNetV2_Contrast(
#   (detail): DetailBranch(
#     (S1_1): ConvBNReLU(
#       (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S1_2): ConvBNReLU(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S2_1): ConvBNReLU(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S2_2): ConvBNReLU(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S2_3): ConvBNReLU(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S3_1): ConvBNReLU(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S3_2): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S3_3): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (segment): SegmentBranch(
#     (S1S2): StemBlock(
#       (conv): ConvBNReLU(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (left_1): ConvBNReLU(
#         (conv): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (left_2): ConvBNReLU(
#         (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (right): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (fuse): ConvBNReLU(
#         (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (S3_1): GELayerS2(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv1): ConvBN(
#         (conv): Conv2d(16, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (dwconv2): ConvBN(
#         (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (shortcut_1): ConvBN(
#         (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (shortcut_2): ConvBN(
#         (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S3_2): GELayerS1(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv): ConvBNReLU(
#         (conv): Conv2d(32, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S4_1): GELayerS2(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv1): ConvBN(
#         (conv): Conv2d(32, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (dwconv2): ConvBN(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (shortcut_1): ConvBN(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (shortcut_2): ConvBN(
#         (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S4_2): GELayerS1(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv): ConvBNReLU(
#         (conv): Conv2d(64, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S5_4_1): GELayerS2(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv1): ConvBN(
#         (conv): Conv2d(64, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (dwconv2): ConvBN(
#         (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (shortcut_1): ConvBN(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (shortcut_2): ConvBN(
#         (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S5_4_2): GELayerS1(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv): ConvBNReLU(
#         (conv): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S5_4_3): GELayerS1(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv): ConvBNReLU(
#         (conv): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S5_4_4): GELayerS1(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv): ConvBNReLU(
#         (conv): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S5_5): CEBlock(
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (conv_gap): ConvBNReLU(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (conv_last): ConvBNReLU(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn): ModuleList(
#           (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         )
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (bga): BGALayer(
#     (left1_convbn): ConvBN(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#     )
#     (left1_conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (left2_convbn): ConvBN(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#     )
#     (left2_pool): AvgPool2d(kernel_size=3, stride=2, padding=1)
#     (right1): ConvBN(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#     )
#     (right2_convbn): ConvBN(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#     )
#     (right2_conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (up1): Upsample(scale_factor=4.0, mode=nearest)
#     (up2): Upsample(scale_factor=4.0, mode=nearest)
#     (conv): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (projHead): ProjectionHead(
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (conv_last): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (head): SegmentHead(
#     (drop): Dropout(p=0.1, inplace=False)
#     (conv): ConvBNReLU(
#       (conv): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (up_sample1): Upsample(scale_factor=2.0, mode=nearest)
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (proj): ConvNorm(
#       (conv): Conv2d(1024, 19, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (up_sample2): Upsample(scale_factor=8.0, mode=bilinear)
#   )
#   (aux2): SegmentHead(
#     (drop): Dropout(p=0.1, inplace=False)
#     (conv): ConvBNReLU(
#       (conv): Conv2d(16, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (up_sample1): Upsample(scale_factor=2.0, mode=nearest)
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(128, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (proj): ConvNorm(
#       (conv): Conv2d(16, 19, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (up_sample2): Upsample(scale_factor=2.0, mode=bilinear)
#   )
#   (aux3): SegmentHead(
#     (drop): Dropout(p=0.1, inplace=False)
#     (conv): ConvBNReLU(
#       (conv): Conv2d(32, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (up_sample1): Upsample(scale_factor=2.0, mode=nearest)
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (proj): ConvNorm(
#       (conv): Conv2d(64, 19, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (up_sample2): Upsample(scale_factor=4.0, mode=bilinear)
#   )
#   (aux4): SegmentHead(
#     (drop): Dropout(p=0.1, inplace=False)
#     (conv): ConvBNReLU(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (up_sample1): Upsample(scale_factor=2.0, mode=nearest)
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (proj): ConvNorm(
#       (conv): Conv2d(256, 19, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (up_sample2): Upsample(scale_factor=8.0, mode=bilinear)
#   )
#   (aux5_4): SegmentHead(
#     (drop): Dropout(p=0.1, inplace=False)
#     (conv): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (up_sample1): Upsample(scale_factor=2.0, mode=nearest)
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(128, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): ModuleList(
#         (0): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=False, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (proj): ConvNorm(
#       (conv): Conv2d(1024, 19, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (up_sample2): Upsample(scale_factor=16.0, mode=bilinear)
#   )
# )

# %%
im = torch.randn(2,3,512,1024)
net.eval()
out = net(im)
net.train()
loss = torch.sum(out['seg'][0][0])
loss.backward()
