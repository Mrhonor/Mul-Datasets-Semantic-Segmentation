# %%
from lib.models.bisenetv2 import BiSeNetV2
import torch

# %%
model = BiSeNetV2(19, 'train', 2, 38)
model.eval()
# Out:
# BiSeNetV2(
#   (detail): DetailBranch(
#     (S1_1): ConvBNReLU(
#       (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (S1_2): ConvBNReLU(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (S2_1): ConvBNReLU(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (S2_2): ConvBNReLU(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (S2_3): ConvBNReLU(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (S3_1): ConvBNReLU(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (S3_2): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (S3_3): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (segment): SegmentBranch(
#     (S1S2): StemBlock(
#       (conv): ConvBNReLU(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (left_1): ConvBNReLU(
#         (conv): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (left_2): ConvBNReLU(
#         (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (right): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (fuse): ConvBNReLU(
#         (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (S3_1): GELayerS2(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv1): ConvBN(
#         (conv): Conv2d(16, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#       )
#       (dwconv2): ConvBN(
#         (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (shortcut_1): ConvBN(
#         (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#       )
#       (shortcut_2): ConvBN(
#         (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S3_2): GELayerS1(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv): ConvBNReLU(
#         (conv): Conv2d(32, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S4_1): GELayerS2(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv1): ConvBN(
#         (conv): Conv2d(32, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       )
#       (dwconv2): ConvBN(
#         (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (shortcut_1): ConvBN(
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#       )
#       (shortcut_2): ConvBN(
#         (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S4_2): GELayerS1(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv): ConvBNReLU(
#         (conv): Conv2d(64, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S5_4_1): GELayerS2(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv1): ConvBN(
#         (conv): Conv2d(64, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       )
#       (dwconv2): ConvBN(
#         (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (shortcut_1): ConvBN(
#         (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#       )
#       (shortcut_2): ConvBN(
#         (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S5_4_2): GELayerS1(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv): ConvBNReLU(
#         (conv): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S5_4_3): GELayerS1(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv): ConvBNReLU(
#         (conv): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S5_4_4): GELayerS1(
#       (conv1): ConvBNReLU(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (dwconv): ConvBNReLU(
#         (conv): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (conv2): ConvBN(
#         (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (S5_5): CEBlock(
#       (conv_gap): ConvBNReLU(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#       (conv_last): ConvBNReLU(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (bga): BGALayer(
#     (left1_convbn): ConvBN(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#     )
#     (left1_conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (left2_convbn): ConvBN(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     )
#     (left2_pool): AvgPool2d(kernel_size=3, stride=2, padding=1)
#     (right1): ConvBN(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (right2_convbn): ConvBN(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#     )
#     (right2_conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (up1): Upsample(scale_factor=4.0, mode=nearest)
#     (up2): Upsample(scale_factor=4.0, mode=nearest)
#     (conv): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#   )
# )

# %%
for name, child in model.named_children():
    print('name: ', name, '\nchild: ', child)
# Out:
# name:  detail
# child:  DetailBranch(
#   (S1_1): ConvBNReLU(
#     (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (relu): ReLU(inplace=True)
#   )
#   (S1_2): ConvBNReLU(
#     (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (relu): ReLU(inplace=True)
#   )
#   (S2_1): ConvBNReLU(
#     (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (relu): ReLU(inplace=True)
#   )
#   (S2_2): ConvBNReLU(
#     (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (relu): ReLU(inplace=True)
#   )
#   (S2_3): ConvBNReLU(
#     (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (relu): ReLU(inplace=True)
#   )
#   (S3_1): ConvBNReLU(
#     (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (relu): ReLU(inplace=True)
#   )
#   (S3_2): ConvBNReLU(
#     (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (relu): ReLU(inplace=True)
#   )
#   (S3_3): ConvBNReLU(
#     (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (relu): ReLU(inplace=True)
#   )
# )
# name:  segment
# child:  SegmentBranch(
#   (S1S2): StemBlock(
#     (conv): ConvBNReLU(
#       (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (left_1): ConvBNReLU(
#       (conv): Conv2d(16, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (left_2): ConvBNReLU(
#       (conv): Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (right): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (fuse): ConvBNReLU(
#       (conv): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (S3_1): GELayerS2(
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (dwconv1): ConvBN(
#       (conv): Conv2d(16, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#     )
#     (dwconv2): ConvBN(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96, bias=False)
#     )
#     (conv2): ConvBN(
#       (conv): Conv2d(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (shortcut_1): ConvBN(
#       (conv): Conv2d(16, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=16, bias=False)
#     )
#     (shortcut_2): ConvBN(
#       (conv): Conv2d(16, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (S3_2): GELayerS1(
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (dwconv): ConvBNReLU(
#       (conv): Conv2d(32, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (conv2): ConvBN(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (S4_1): GELayerS2(
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (dwconv1): ConvBN(
#       (conv): Conv2d(32, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#     )
#     (dwconv2): ConvBN(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#     )
#     (conv2): ConvBN(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (shortcut_1): ConvBN(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False)
#     )
#     (shortcut_2): ConvBN(
#       (conv): Conv2d(32, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (S4_2): GELayerS1(
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (dwconv): ConvBNReLU(
#       (conv): Conv2d(64, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (conv2): ConvBN(
#       (conv): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (S5_4_1): GELayerS2(
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (dwconv1): ConvBN(
#       (conv): Conv2d(64, 384, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#     )
#     (dwconv2): ConvBN(
#       (conv): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#     )
#     (conv2): ConvBN(
#       (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (shortcut_1): ConvBN(
#       (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=64, bias=False)
#     )
#     (shortcut_2): ConvBN(
#       (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (S5_4_2): GELayerS1(
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (dwconv): ConvBNReLU(
#       (conv): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (conv2): ConvBN(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (S5_4_3): GELayerS1(
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (dwconv): ConvBNReLU(
#       (conv): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (conv2): ConvBN(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (S5_4_4): GELayerS1(
#     (conv1): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (dwconv): ConvBNReLU(
#       (conv): Conv2d(128, 768, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (conv2): ConvBN(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     )
#     (relu): ReLU(inplace=True)
#   )
#   (S5_5): CEBlock(
#     (conv_gap): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#     (conv_last): ConvBNReLU(
#       (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (relu): ReLU(inplace=True)
#     )
#   )
# )
# name:  bga
# child:  BGALayer(
#   (left1_convbn): ConvBN(
#     (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#   )
#   (left1_conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (left2_convbn): ConvBN(
#     (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (left2_pool): AvgPool2d(kernel_size=3, stride=2, padding=1)
#   (right1): ConvBN(
#     (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
#   (right2_convbn): ConvBN(
#     (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=128, bias=False)
#   )
#   (right2_conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (up1): Upsample(scale_factor=4.0, mode=nearest)
#   (up2): Upsample(scale_factor=4.0, mode=nearest)
#   (conv): ConvBNReLU(
#     (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (relu): ReLU(inplace=True)
#   )
# )

# %%
state = torch.load('model_3000.pth')

# %%
for i in state['bga']:
    print(i)
# Out:
# left1.0.weight
# left1.1.weight
# left1.1.bias
# left1.1.running_mean
# left1.1.running_var
# left1.1.num_batches_tracked
# left1.2.weight
# left2.0.weight
# left2.1.weight
# left2.1.bias
# left2.1.running_mean
# left2.1.running_var
# left2.1.num_batches_tracked
# right1.0.weight
# right1.1.weight
# right1.1.bias
# right1.1.running_mean
# right1.1.running_var
# right1.1.num_batches_tracked
# right2.0.weight
# right2.1.weight
# right2.1.bias
# right2.1.running_mean
# right2.1.running_var
# right2.1.num_batches_tracked
# right2.2.weight
# conv.0.weight
# conv.1.weight
# conv.1.bias
# conv.1.running_mean
# conv.1.running_var
# conv.1.num_batches_tracked

# %%
detail_state = {}
detail_state['S1_1.conv.weight'] = state['detail']['S1.0.conv.weight']
detail_state['S1_2.conv.weight'] = state['detail']['S1.1.conv.weight']
detail_state['S2_1.conv.weight'] = state['detail']['S2.0.conv.weight']
detail_state['S2_2.conv.weight'] = state['detail']['S2.1.conv.weight']
detail_state['S2_3.conv.weight'] = state['detail']['S2.2.conv.weight']
detail_state['S3_1.conv.weight'] = state['detail']['S3.0.conv.weight']
detail_state['S3_2.conv.weight'] = state['detail']['S3.1.conv.weight']
detail_state['S3_3.conv.weight'] = state['detail']['S3.2.conv.weight']

segment_state = {}
segment_state['S1S2.conv.conv.weight'] = state['segment']['S1S2.conv.conv.weight']
segment_state['S1S2.left_1.conv.weight'] = state['segment']['S1S2.left.0.conv.weight']
segment_state['S1S2.left_2.conv.weight'] = state['segment']['S1S2.left.1.conv.weight']
segment_state['S1S2.fuse.conv.weight'] = state['segment']['S1S2.fuse.conv.weight']

def loadGELayerS2(srcDict, src_name, targerdict, target_name):
    targerdict[target_name+'.conv1.conv.weight'] = srcDict[src_name+'.conv1.conv.weight']
    targerdict[target_name+'.dwconv1.conv.weight'] = srcDict[src_name+'.dwconv1.0.weight']
    targerdict[target_name+'.dwconv2.conv.weight'] = srcDict[src_name+'.dwconv2.0.weight']
    targerdict[target_name+'.conv2.conv.weight'] = srcDict[src_name+'.conv2.0.weight']
    targerdict[target_name+'.shortcut_1.conv.weight'] = srcDict[src_name+'.shortcut.0.weight']
    targerdict[target_name+'.shortcut_2.conv.weight'] = srcDict[src_name+'.shortcut.2.weight']

def loadGELayerS1(srcDict, src_name, targerdict, target_name):
    targerdict[target_name+'.conv1.conv.weight'] = srcDict[src_name+'.conv1.conv.weight']
    targerdict[target_name+'.dwconv.conv.weight'] = srcDict[src_name+'.dwconv.0.weight']
    targerdict[target_name+'.conv2.conv.weight'] = srcDict[src_name+'.conv2.0.weight']
    
loadGELayerS2(state['segment'], 'S3.0', segment_state, 'S3_1')
loadGELayerS1(state['segment'], 'S3.1', segment_state, 'S3_2')
loadGELayerS2(state['segment'], 'S4.0', segment_state, 'S4_1')
loadGELayerS1(state['segment'], 'S4.1', segment_state, 'S4_2')
loadGELayerS2(state['segment'], 'S5_4.0', segment_state, 'S5_4_1')
loadGELayerS1(state['segment'], 'S5_4.1', segment_state, 'S5_4_2')
loadGELayerS1(state['segment'], 'S5_4.2', segment_state, 'S5_4_3')
loadGELayerS1(state['segment'], 'S5_4.3', segment_state, 'S5_4_4')
segment_state['S5_5.conv_gap.conv.weight'] = state['segment']['S5_5.conv_gap.conv.weight']
segment_state['S5_5.conv_last.conv.weight'] = state['segment']['S5_5.conv_last.conv.weight']

bga_state = {}
bga_state['left1_convbn.conv.weight'] = state['bga']['left1.0.weight']
bga_state['left1_conv.weight'] = state['bga']['left1.2.weight']
bga_state['left2_convbn.conv.weight'] = state['bga']['left2.0.weight']
bga_state['right1.conv.weight'] = state['bga']['right1.0.weight']
bga_state['right2_convbn.conv.weight'] = state['bga']['right2.0.weight']
bga_state['right2_conv.weight'] = state['bga']['right2.2.weight']
bga_state['conv.conv.weight'] = state['bga']['conv.0.weight']

# %%
model.detail.load_state_dict(detail_state, strict=True)
model.segment.load_state_dict(segment_state, strict=True)
model.bga.load_state_dict(bga_state, strict=True)
# Out:
# <All keys matched successfully>

# %%
print(state.keys())
# Out:
# odict_keys(['detail.S1_1.conv.weight', 'detail.S1_2.conv.weight', 'detail.S2_1.conv.weight', 'detail.S2_2.conv.weight', 'detail.S2_3.conv.weight', 'detail.S3_1.conv.weight', 'detail.S3_2.conv.weight', 'detail.S3_3.conv.weight', 'segment.S1S2.conv.conv.weight', 'segment.S1S2.left_1.conv.weight', 'segment.S1S2.left_2.conv.weight', 'segment.S1S2.fuse.conv.weight', 'segment.S3_1.conv1.conv.weight', 'segment.S3_1.dwconv1.conv.weight', 'segment.S3_1.dwconv2.conv.weight', 'segment.S3_1.conv2.conv.weight', 'segment.S3_1.shortcut_1.conv.weight', 'segment.S3_1.shortcut_2.conv.weight', 'segment.S3_2.conv1.conv.weight', 'segment.S3_2.dwconv.conv.weight', 'segment.S3_2.conv2.conv.weight', 'segment.S4_1.conv1.conv.weight', 'segment.S4_1.dwconv1.conv.weight', 'segment.S4_1.dwconv2.conv.weight', 'segment.S4_1.conv2.conv.weight', 'segment.S4_1.shortcut_1.conv.weight', 'segment.S4_1.shortcut_2.conv.weight', 'segment.S4_2.conv1.conv.weight', 'segment.S4_2.dwconv.conv.weight', 'segment.S4_2.conv2.conv.weight', 'segment.S5_4_1.conv1.conv.weight', 'segment.S5_4_1.dwconv1.conv.weight', 'segment.S5_4_1.dwconv2.conv.weight', 'segment.S5_4_1.conv2.conv.weight', 'segment.S5_4_1.shortcut_1.conv.weight', 'segment.S5_4_1.shortcut_2.conv.weight', 'segment.S5_4_2.conv1.conv.weight', 'segment.S5_4_2.dwconv.conv.weight', 'segment.S5_4_2.conv2.conv.weight', 'segment.S5_4_3.conv1.conv.weight', 'segment.S5_4_3.dwconv.conv.weight', 'segment.S5_4_3.conv2.conv.weight', 'segment.S5_4_4.conv1.conv.weight', 'segment.S5_4_4.dwconv.conv.weight', 'segment.S5_4_4.conv2.conv.weight', 'segment.S5_5.conv_gap.conv.weight', 'segment.S5_5.conv_last.conv.weight', 'bga.left1_convbn.conv.weight', 'bga.left1_conv.weight', 'bga.left2_convbn.conv.weight', 'bga.right1.conv.weight', 'bga.right2_convbn.conv.weight', 'bga.right2_conv.weight', 'bga.conv.conv.weight'])
